# %% [markdown]
# # =======================================
# # PERTEMUAN 1: Pengenalan Data Science
# # =======================================
# * Nama: Nida'an Khafiyya
# * NIM: 250401020123
# * Kelas: IF401

# %% [markdown]
# ## SEL 1: Output sederhana

# %%
print("Hello, Data Science!")
print("Selamat datang di mata kuliah Pengantar Data Science!")
# Out:
# Hello, Data Science!
# Selamat datang di mata kuliah Pengantar Data Science!

# %% [markdown]
# ## SEL 2: Variabel dan tipe data dasar

# %%
nama      = "Nida'an Khafiyya"    # String
angkatan  = 2025                  # Integer
ipk       = 4.0                   # Float
aktif     = True                  # Boolean

print(f"Nama      : {nama}")
print(f"Angkatan  : {angkatan}")
print(f"IPK       : {ipk}")
print(f"Aktif     : {aktif}")
# Out:
# Nama      : Nida'an Khafiyya
# Angkatan  : 2025
# IPK       : 4.0
# Aktif     : True

# %% [markdown]
# ## SEL 3: List dan perulangan

# %%
tools = ["Python", "Google Colab", "Jupyter Notebook", "GitHub"]
print("\nTools Data Science yang akan kita pelajari:")
for i, tool in enumerate(tools, 1):
  print(f"  {i}. {tool}")
# Out:
# Tools Data Science yang akan kita pelajari:
#   1. Python
#   2. Google Colab
#   3. Jupyter Notebook
#   4. GitHub

# %% [markdown]
# ## SEL 4: Fungsi sederhana

# %%
def perkenalan(nama, prodi, angkatan):
  """Fungsi untuk menampilkan perkenalan mahasiswa."""
  return f"Hai! Saya {nama} dari {prodi}, angkatan {angkatan}."

hasil = perkenalan("Nida'an Khafiyya", "Informatika", 2025)
print(hasil)
# Out:
# Hai! Saya Nida'an Khafiyya dari Informatika, angkatan 2025.

# %% [markdown]
# ## Kesimpulan
#
# Pada pertemuan pertama ini, telah dipelajari dasar-dasar penggunaan Python dalam lingkungan Google Colab sebagai langkah awal untuk mempelajari Data Science. Materi yang dipelajari meliputi penggunaan perintah output (`print`), pembuatan variabel dengan berbagai tipe data (string, integer, float, dan boolean), penggunaan list dan perulangan (`for`), serta pembuatan fungsi sederhana dengan parameter dan nilai balik (`return`).
#
# Temuan utama dari praktikum ini adalah bahwa Python memiliki sintaks yang sederhana dan mudah dipahami untuk mengolah data serta membuat program dasar. Selain itu, penggunaan fungsi membantu membuat kode lebih terstruktur dan dapat digunakan kembali, sedangkan list dan perulangan mempermudah pengolahan kumpulan data secara otomatis.
#
# Keterbatasan pada pertemuan ini adalah materi masih berfokus pada konsep dasar pemrograman dan belum membahas pengolahan data yang menjadi inti Data Science. Pertanyaan yang muncul adalah bagaimana konsep-konsep dasar Python ini akan diterapkan pada analisis data nyata, seperti membaca dataset, melakukan pembersihan data, dan membuat visualisasi data pada pertemuan berikutnya.
